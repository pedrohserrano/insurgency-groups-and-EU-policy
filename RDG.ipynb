# %%
import pandas as pd

# %%
table = pd.read_stata('datasets/RGD main.dta')

# %%
table.head(10)
# Out:
#    cnumb ccode clust2 cowccode cow01conflict cow94conflict  countryname  yrst  \
# 0      1  AFG1    AFG      700           698           901  Afghanistan  1978
# 1      2  AFG2    AFG      700           698           901  Afghanistan  1992
# 2      4  ALG1    ALG      615           659           844      Algeria  1962
# 3      5  ALG2    ALG      615           739                    Algeria  1992
# 4      6  ANG1    ANG      540           693           898       Angola  1975
# 5      7  ANG2    ANG      540           743           982       Angola  1992
# 6      8  ANG3    ANG      540           743           982       Angola  1997
# 7      9  ANG4    ANG      540                                   Angola  1994
# 8     10  ARG1    ARG      160           647           820    Argentina  1955
# 9     11  ARG2    ARG      160                                Argentina  1975
#
#    most  yrend  ...  polch5 polch10  polch15  polch0  poldif003  poldif005  \
# ...

# %%
table.columns
# Out:
# Index(['cnumb', 'ccode', 'clust2', 'cowccode', 'cow01conflict',
#        'cow94conflict', 'countryname', 'yrst', 'most', 'yrend',
#        ...
#        'polch5', 'polch10', 'polch15', 'polch0', 'poldif003', 'poldif005',
#        'poldif0010', 'poldif0015', 'techreb', 'techreb12'],
#       dtype='object', length=128)
