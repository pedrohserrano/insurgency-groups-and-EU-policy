# %% [markdown]
# ## Acled data

# %%
import pandas as pd

# %%
acled = pd.read_csv('../Downloads/1900-01-01-2020-06-23.csv')

# %%
acled.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty    event_date  year  \
# 0  7131137  760      SYR79353             79353  20 June 2020  2020
# 1  7129090  364       IRN6603              6603  20 June 2020  2020
# 2  7129860  788       TUN6686              6686  20 June 2020  2020
# 3  7130116  120       CAO3402              3402  20 June 2020  2020
# 4  7129606  484      MEX19779             19779  20 June 2020  2020
#
#    time_precision                  event_type                 sub_event_type  \
# 0               1  Explosions/Remote violence  Remote explosive/landmine/IED
# 1               1                    Protests               Peaceful protest
# 2               1                    Protests               Peaceful protest
# 3               2                     Battles                    Armed clash
# 4               1                    Protests               Peaceful protest
#
#                                 actor1  ...           location  latitude  \
# ...

# %%
acled.columns
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'region', 'country', 'admin1', 'admin2', 'admin3',
#        'location', 'latitude', 'longitude', 'geo_precision', 'source',
#        'source_scale', 'notes', 'fatalities', 'timestamp', 'iso3'],
#       dtype='object')

# %%
acled.groupby('actor1').sum()['fatalities'].reset_index().sort_values('fatalities', ascending=False).head(20)
# Out:
#                                                  actor1  fatalities
# 4601                  Military Forces of Angola (1975-)      122346
# 4662            Military Forces of Ethiopia (1995-2018)       88397
# 4593             Military Forces of Afghanistan (2014-)       76160
# 5032  Military Forces of Yemen (2016-) Supreme Polit...       55060
# 4918                   Military Forces of Syria (2000-)       37399
# 4714                Military Forces of Iraq (2014-2018)       33000
# 7952                                            Taliban       26961
# 3035                               Islamic State (Iraq)       25878
# 5001                   Military Forces of Yemen (2012-)       24540
# 4906               Military Forces of Sudan (1989-2019)       23851
# 2375                     Global Coalition Against Daesh       20594
# 8199  UNITA: National Union for the Total Independen...       18444
# 5866                           Operation Restoring Hope       18394
# ...

# %%
len(acled.actor1.unique())
# Out:
# 8770

# %%
acled.groupby('actor1').count()['data_id'].reset_index().sort_values('data_id', ascending=False).head(20)
# Out:
#                                                  actor1  data_id
# 6865                                 Protesters (India)    53662
# 6903                              Protesters (Pakistan)    41056
# 4918                   Military Forces of Syria (2000-)    31178
# 7952                                            Taliban    26242
# 5866                           Operation Restoring Hope    20310
# 5032  Military Forces of Yemen (2016-) Supreme Polit...    15663
# 5477            NAF: United Armed Forces of Novorossiya    15133
# 4593             Military Forces of Afghanistan (2014-)    12672
# 7227                                    Rioters (India)    12425
# 4988             Military Forces of Ukraine (2014-2019)    12241
# 4605                 Military Forces of Artsakh (2007-)     9556
# 8390                   Unidentified Armed Group (Syria)     7796
# 7179                               Rioters (Bangladesh)     7656
# ...

# %%
acled.groupby('sub_event_type').count()['data_id'].reset_index().sort_values('data_id')
# Out:
#                          sub_event_type  data_id
# 7                       Chemical weapon      112
# 12     Headquarters or base established     1080
# 1                             Agreement     1551
# 23                         Suicide bomb     1835
# 21                      Sexual violence     2290
# 9    Excessive force against protesters     2922
# 16    Non-violent transfer of territory     3443
# 17                                Other     3739
# 11                              Grenade     4153
# 4                               Arrests     4775
# 15  Non-state actor overtakes territory     4948
# 8                 Disrupted weapons use     5263
# 0        Abduction/forced disappearance     7622
# 6              Change to group/activity     7886
# 10         Government regains territory     8353
# 13         Looting/property destruction     9266
# 19            Protest with intervention    15386
# 14                         Mob violence    28851
# ...

# %%
gdeltsample = pd.read_csv('../Downloads/20191103.export.CSV', sep='\t')

# %%
gdeltsample
# Out:
#        884006421  20181103  201811  2018  2018.8301 Unnamed: 5  Unnamed: 6  \
# 0      884006422  20181103  201811  2018  2018.8301        NaN         NaN
# 1      884006423  20181103  201811  2018  2018.8301        NaN         NaN
# 2      884006424  20181103  201811  2018  2018.8301        NaN         NaN
# 3      884006425  20181103  201811  2018  2018.8301        CUB       CUBAN
# 4      884006426  20181103  201811  2018  2018.8301        CUB       CUBAN
# ...          ...       ...     ...   ...        ...        ...         ...
# 87074  884140720  20191103  201911  2019  2019.8301     YEMMED        SANA
# 87075  884140721  20191103  201911  2019  2019.8301     YEMMED        SANA
# 87076  884140722  20191103  201911  2019  2019.8301        idg  INDIGENOUS
# 87077  884140723  20191103  201911  2019  2019.8301        idg  INDIGENOUS
# 87078  884140724  20191103  201911  2019  2019.8301        idg  INDIGENOUS
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  -1113265 4.1  \
# ...
