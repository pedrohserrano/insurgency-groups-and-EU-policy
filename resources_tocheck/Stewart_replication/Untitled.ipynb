# %%
import pandas as pd

# %%
MAS_Main_Data_CS = pd.read_stata('MAS_Main Data_CS.dta')
MAS_Main_Data_Panel = pd.read_stata('MAS_Main Data_Panel.dta')
MAS_Original_Data_CS = pd.read_stata('MAS_Original Data_CS.dta')
MAS_Original_Data_Panel = pd.read_stata('MAS_Original Data_Panel.dta')

# %%
MAS_Main_Data_Panel.head()
# Out:
#    acr        id        obsid  confid    dyadid  dyadperiod        side_a  \
# 0  NTH  NTH-1945  EACD.2.2-19    1050    1050-1           1   Netherlands
# 1  BOL  BOL-1946   EACD.2.2-1  1010.1  1010.1-1           1       Bolivia
# 2  NTH  NTH-1946  EACD.2.2-19    1050    1050-1           1   Netherlands
# 3  RUS  RUS-1946  EACD.2.2-55    1120    1120-1           1  Soviet Union
# 4  RUS  RUS-1946  EACD.2.2-64    1140    1140-1           1  Soviet Union
#
#                            side_b      location    year  \
# 0         Indonesian Peoples Army     Indonesia  1945.0
# 1  Popular Revolutionary Movement       Bolivia  1946.0
# 2         Indonesian Peoples Army     Indonesia  1946.0
# 3                         LTS[p]A  Soviet Union  1946.0
# 4                             UPA  Soviet Union  1946.0
#
#              ...             yearnohealthcount  yearexclusivehealthcount  \
# 0            ...                           1.0                       0.0
# 1            ...                           3.0                       7.0
# 2            ...                           3.0                       7.0
# 3            ...                           3.0                       7.0
# 4            ...                           3.0                       7.0
#
#    exclude                                            id_use  \
# 0      NaN   Indonesian Peoples ArmyNetherlandsIndonesia1945
# 1      0.0  Popular Revolutionary MovementBoliviaBolivia1946
# 2      NaN   Indonesian Peoples ArmyNetherlandsIndonesia1946
# 3      0.0               LTS[p]ASoviet UnionSoviet Union1946
# 4      0.0                   UPASoviet UnionSoviet Union1946
#
#    yearpubeducountsec  yearpubeducountnonsec  countnonsec  countsec  \
# 0                 NaN                    0.0          1.0       NaN
# 1                 NaN                    NaN          NaN       NaN
# 2                 NaN                    0.0          6.0       NaN
# 3                 NaN                    NaN          NaN       NaN
# 4                 NaN                    NaN          NaN       NaN
#
#    yearpubhealthcountsec  yearpubhealthcountnonsec
# 0                    NaN                       0.0
# 1                    NaN                       NaN
# 2                    NaN                       0.0
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
# [5 rows x 178 columns]

# %%
MAS_Main_Data_Panel[['id_use','yearpubhealthcountsec','yearpubhealthcountnonsec','yearpubeducountsec','yearpubeducountnonsec']]
# Out:
#                                                  id_use  \
# 0       Indonesian Peoples ArmyNetherlandsIndonesia1945
# 1      Popular Revolutionary MovementBoliviaBolivia1946
# 2       Indonesian Peoples ArmyNetherlandsIndonesia1946
# 3                   LTS[p]ASoviet UnionSoviet Union1946
# 4                       UPASoviet UnionSoviet Union1946
# 5            Viet Nam Doc Dong Min HoiFranceVietnam1946
# 6                      LNPASoviet UnionSoviet Union1946
# 7                   IZL [Etzel]United KingdomIsrael1946
# 8                              Lao IssaraFranceLaos1946
# 9                         HukPhilippinesPhilippines1946
# 10          Forest BrothersSoviet UnionSoviet Union1946
# 11               Republic of Kurdistan/KDPIIranIran1946
# 12                      Khmer IssarakFranceCambodia1946
# 13                Peoples Liberation ArmyChinaChina1946
# 14                     BDPSSoviet UnionSoviet Union1946
# 15                                  DSEGreeceGreece1946
# 16                             MDRMFranceMadagascar1947
# 17    Opposition coalition [Febreristas, Liberals an...
# 18                            CPIHyderabadHyderabad1947
# 19                      UPASoviet UnionSoviet Union1947
# 20                        HukPhilippinesPhilippines1947
# 21      Indonesian Peoples ArmyNetherlandsIndonesia1947
# 22                             Lao IssaraFranceLaos1947
# 23                     LNPASoviet UnionSoviet Union1947
# 24          Forest BrothersSoviet UnionSoviet Union1947
# 25                Peoples Liberation ArmyChinaChina1947
# 26                     BDPSSoviet UnionSoviet Union1947
# 27                      Khmer IssarakFranceCambodia1947
# 28                  LTS[p]ASoviet UnionSoviet Union1947
# 29                                  DSEGreeceGreece1947
# ...                                                 ...
# 2301                            BDSF/NDFBIndiaIndia2003
# 2302                          GAMIndonesiaIndonesia2003
# 2303                                  MCCIndiaIndia2003
# 2304                      NPAPhilippinesPhilippines2003
# 2305                   Kashmir InsurgentsIndiaIndia2003
# 2306                            PFLP-GCIsraelIsrael2003
# 2307                                 UNLFIndiaIndia2003
# 2308                             LURDLiberiaLiberia2003
# 2309                                  KNUBurmaBurma2003
# 2310                                LRAUgandaUganda2003
# 2311                               PFLPIsraelIsrael2003
# 2312                     MILFPhilippinesPhilippines2003
# 2313                            ELNColombiaColombia2003
# 2314                  TalibanAfghanistanAfghanistan2003
# 2315                                  SSABurmaBurma2003
# 2316                   Palipehutu-FNLBurundiBurundi2003
# 2317                         LTTESri LankaSri Lanka2003
# 2318                           ONLFEthiopiaEthiopia2003
# 2319                                 NLFTIndiaIndia2003
# 2320                                ADFUgandaUganda2003
# 2321                        Naxalites/PWGIndiaIndia2003
# 2322                            CPN-M/UPFNepalNepal2003
# 2323                              GIAAlgeriaAlgeria2003
# 2324                                 SPLMSudanSudan2003
# 2325                                 BLTFIndiaIndia2003
# 2326                           FARCColombiaColombia2003
# 2327                                AMBIsraelIsrael2003
# 2328                         UFLA FactionIndiaIndia2003
# 2329                                 ATTFIndiaIndia2003
# 2330                               FLECAngolaAngola2003
#
#       yearpubhealthcountsec  yearpubhealthcountnonsec  yearpubeducountsec  \
# 0                       NaN                       0.0                 NaN
# 1                       NaN                       NaN                 NaN
# 2                       NaN                       0.0                 NaN
# 3                       NaN                       NaN                 NaN
# 4                       NaN                       NaN                 NaN
# 5                       NaN                       0.0                 NaN
# 6                       NaN                       NaN                 NaN
# 7                       NaN                       NaN                 NaN
# 8                       NaN                       NaN                 NaN
# 9                       NaN                       0.0                 NaN
# 10                      NaN                       NaN                 NaN
# 11                      0.0                       NaN                 0.0
# 12                      NaN                       0.0                 NaN
# 13                      NaN                       0.0                 NaN
# 14                      NaN                       NaN                 NaN
# 15                      NaN                       0.0                 NaN
# 16                      NaN                       0.0                 NaN
# 17                      NaN                       0.0                 NaN
# 18                      NaN                       NaN                 NaN
# 19                      NaN                       NaN                 NaN
# 20                      NaN                       0.0                 NaN
# 21                      NaN                       0.0                 NaN
# 22                      NaN                       NaN                 NaN
# 23                      NaN                       NaN                 NaN
# 24                      NaN                       NaN                 NaN
# 25                      NaN                       0.0                 NaN
# 26                      NaN                       NaN                 NaN
# 27                      NaN                       0.0                 NaN
# 28                      NaN                       NaN                 NaN
# 29                      NaN                       0.0                 NaN
# ...                     ...                       ...                 ...
# 2301                    NaN                       NaN                 NaN
# 2302                    3.0                       NaN                 4.0
# 2303                    NaN                       NaN                 NaN
# 2304                    NaN                       1.0                 NaN
# 2305                    NaN                       NaN                 NaN
# 2306                    NaN                       NaN                 NaN
# 2307                    NaN                       NaN                 NaN
# 2308                    NaN                       NaN                 NaN
# 2309                    3.0                       NaN                 4.0
# 2310                    NaN                       NaN                 NaN
# 2311                    NaN                       NaN                 NaN
# 2312                    NaN                       NaN                 NaN
# 2313                    NaN                       1.0                 NaN
# 2314                    NaN                       NaN                 NaN
# 2315                    3.0                       NaN                 4.0
# 2316                    NaN                       NaN                 NaN
# 2317                    3.0                       NaN                 4.0
# 2318                    NaN                       NaN                 NaN
# 2319                    NaN                       NaN                 NaN
# 2320                    NaN                       NaN                 NaN
# 2321                    NaN                       NaN                 NaN
# 2322                    NaN                       1.0                 NaN
# 2323                    NaN                       NaN                 NaN
# 2324                    NaN                       1.0                 NaN
# 2325                    NaN                       NaN                 NaN
# 2326                    NaN                       1.0                 NaN
# 2327                    NaN                       NaN                 NaN
# 2328                    3.0                       NaN                 4.0
# 2329                    NaN                       NaN                 NaN
# 2330                    NaN                       NaN                 NaN
#
#       yearpubeducountnonsec
# 0                       0.0
# 1                       NaN
# 2                       0.0
# 3                       NaN
# 4                       NaN
# 5                       0.0
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       0.0
# 10                      NaN
# 11                      NaN
# 12                      0.0
# 13                      0.0
# 14                      NaN
# 15                      0.0
# 16                      0.0
# 17                      0.0
# 18                      NaN
# 19                      NaN
# 20                      0.0
# 21                      0.0
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      0.0
# 26                      NaN
# 27                      0.0
# 28                      NaN
# 29                      0.0
# ...                     ...
# 2301                    NaN
# 2302                    NaN
# 2303                    NaN
# 2304                    0.0
# 2305                    NaN
# 2306                    NaN
# 2307                    NaN
# 2308                    NaN
# 2309                    NaN
# 2310                    NaN
# 2311                    NaN
# 2312                    NaN
# 2313                    0.0
# 2314                    NaN
# 2315                    NaN
# 2316                    NaN
# 2317                    NaN
# 2318                    NaN
# 2319                    NaN
# 2320                    NaN
# 2321                    NaN
# 2322                    0.0
# 2323                    NaN
# 2324                    0.0
# 2325                    NaN
# 2326                    0.0
# 2327                    NaN
# 2328                    NaN
# 2329                    NaN
# 2330                    NaN
#
# [2331 rows x 5 columns]

# %%
for i in MAS_Main_Data_Panel.columns:
    print(i)
# Out:
# acr
# id
# obsid
# confid
# dyadid
# dyadperiod
# side_a
# side_b
# location
# year
# pg
# sec2
# communist
# ethnonsec
# dur
# l1imr
# l1gdppc_log
# l1democracy
# l1totalpop_log
# totalpop_change_log
# lmtnest
# rebord
# rs1
# rs2
# rs3
# rs4
# nonmilex
# logrs
# groups2
# bd_best_low_log
# preconflict_edu
# preconflict_health
# regionnum1
# regionnum2
# regionnum3
# regionnum4
# dec40
# dec50
# dec60
# dec70
# dec80
# dec90
# terrcontrol
# locnum1
# locnum2
# locnum3
# locnum4
# locnum5
# locnum6
# locnum7
# locnum8
# locnum9
# locnum10
# locnum11
# locnum12
# locnum13
# locnum14
# locnum15
# locnum16
# locnum17
# locnum18
# locnum19
# locnum20
# locnum21
# locnum22
# locnum23
# locnum24
# locnum25
# locnum26
# locnum27
# locnum28
# locnum29
# locnum30
# locnum31
# locnum32
# locnum33
# locnum34
# locnum35
# locnum36
# locnum37
# locnum38
# locnum39
# locnum40
# locnum41
# locnum42
# locnum43
# locnum44
# locnum45
# locnum46
# locnum47
# locnum48
# locnum49
# locnum50
# locnum51
# locnum52
# locnum53
# locnum54
# locnum55
# locnum56
# locnum57
# locnum58
# locnum59
# locnum60
# locnum61
# locnum62
# locnum63
# locnum64
# locnum65
# locnum66
# locnum67
# locnum68
# locnum69
# locnum70
# locnum71
# locnum72
# locnum73
# locnum74
# locnum75
# locnum76
# locnum77
# locnum78
# locnum79
# locnum80
# locnum81
# locnum82
# locnum83
# locnum84
# locnum85
# locnum86
# locnum87
# locnum88
# locnum89
# locnum90
# locnum91
# locnum92
# locnum93
# locnum94
# locnum95
# locnum96
# locnum97
# locnum98
# locnum99
# locnum100
# locnum101
# locnum102
# locnum103
# locnum104
# locnum105
# locnum106
# locnum107
# locnum108
# locnum109
# pg_zero
# pg_one
# pg_alt
# pgb
# pg_ord
# seccol
# secbroad3
# secbroad4
# yearmin
# yearpubeducount
# yearcount
# yearpubhealthcount
# eduannual
# healthannual
# yearnoeducount
# yearexclusiveeducount
# yearnohealthcount
# yearexclusivehealthcount
# exclude
# id_use
# yearpubeducountsec
# yearpubeducountnonsec
# countnonsec
# countsec
# yearpubhealthcountsec
# yearpubhealthcountnonsec

# %%
"""
****FIGURES A.4 and A.5: Education or Health Care Provision by Goals, Overtime (Panel)***
label var yearpubhealthcountnonsec"Inclusive Services, Non-Secessionist"
label var yearpubhealthcountsec "Inclusive Services, Secessionist"
label var countnonsec "Non-Secessionist"
label var yearpubeducountnonsec "Inclusive Services, Non-Secessionist"
label var countsec "Secessionist"
label var yearpubeducountsec "Inclusive Services, Secessionist"
"""
